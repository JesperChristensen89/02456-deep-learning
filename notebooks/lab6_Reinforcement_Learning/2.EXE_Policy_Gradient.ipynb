# %% [markdown]
# # Policy Gradient
#
# > <span style="color:gray">
# Created by Jonas Busk ([jbusk@dtu.dk](mailto:jbusk@dtu.dk)).
# </span>
#
# In this part, we will create an agent that can learn to solve tasks from OpenAI Gym by applying the Policy Gradient method. We will implement the agent with a probabilistic policy, that given a state of the environment, $s$, outputs a probability distribution over available actions, $a$:
#
# $$
# p_\theta(a|s)
# $$
#
# Since this is a deep learning course, we will model the policy as a neural network with parameters $\theta$ and train it with gradient descent (now the name 'Policy Gradient' should start to make sense).
# When the set of available actions is discrete, we can use a network with softmax output.
#
# The core idea of training the policy network is simple: *we want to maximize the expected total reward by increasing the probability of good actions and decreasing the probability of bad actions*.
#
# The expectation over the (discounted) total reward, $R$, is:
#
# $$
# \mathbb{E}[R|\theta] = \int p_\theta({\bf a}|{\bf s}) R({\bf a}) d{\bf a} \ ,
# $$
#
# where ${\bf a} = a_1,\ldots,a_T$, ${\bf s}=s_1,\ldots,s_T$.
#
# Then we can use the gradient to maximize the total reward:
#
# $$
# \begin{align}
# \nabla_\theta \mathbb{E}[R|\theta] &= \nabla_\theta \int p_\theta({\bf a}|{\bf s}) R({\bf a}) \, d{\bf a} \\
# &= \int \nabla_\theta p_\theta({\bf a}|{\bf s}) R({\bf a})  \, d{\bf a} \\
# &= \int p_\theta({\bf a}|{\bf s}) \nabla_\theta \log p_\theta({\bf a}|{\bf s}) R({\bf a}) \, d{\bf a} \\
# &= \mathbb{E}[R({\bf a}) \nabla_\theta \log p_\theta({\bf a}|{\bf s})]
# \end{align}
# $$
#
# using the identity
#
# $$
# \nabla_\theta p_\theta({\bf a}|{\bf s}) = p_\theta({\bf a}|{\bf s}) \nabla_\theta \log p_\theta({\bf a}|{\bf s})
# $$
#
# to express the gradient as an average over $p_\theta({\bf a},{\bf s})$.
#
# We cannot evaluate the average over roll-outs analytically, but we have an environment simulator that when supplied with our current policy $p_\theta(a|s)$ can return the sequence of action, states and rewards. This allows us to replace the integral by a Monte Carlo average over $V$ roll-outs:
#
# $$
# \nabla_\theta \mathbb{E}[R|\theta] \approx \frac{1}{V} \sum_{v=1}^V \nabla_\theta \log p_\theta({\bf a}^{(v)}|{\bf s}^{(v)}) R({\bf a}^{(v)}) \ .
# $$
#
# In practice, to reduce the variance of the gradient, instead of $R$, we use the adjusted discounted future reward, also known as the *advantage*, $A$:
#
# $$
# A_t = R_t - b_t \ ,
# $$
#
# where the *baseline*, $b_t$, is the (discounted) total future reward at timestep $t$ averaged over the $V$ roll-outs:
#
# $$
# b_t = \frac{1}{V} \sum_{v=1}^V R_t^{(v)} \ .
# $$
#
# This way we are always encouraging and discouraging roughly half of the performed actions, which gives us the final gradient estimator:
#
# $$
# \nabla_\theta \mathbb{E}[R|\theta] \approx \frac{1}{V} \sum_{v=1}^V \nabla_\theta \log p_\theta({\bf a}^{(v)}|{\bf s}^{(v)}) A({\bf a}^{(v)})
# $$
#
# And that's it! Please refer to [this blog post](http://karpathy.github.io/2016/05/31/rl/) by Karpathy for more discussion on the Policy Gradient method.
#
# --
#
# *Note: For simple reinforcement learning problems (like the one we will address in this exercise) there are simpler methods that work just fine. However, the Policy Gradient method has been shown to also work well for complex problems with high dimensional inputs and many parameters, where simple methods become inadequate.*

# %% [markdown]
# ## Policy Gradient code

# %%
# imports
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow.python.ops.nn import relu, softmax
import gym
from utils import Viewer

# %% [markdown]
# In this lab we will work with the [CartPole-v0](https://gym.openai.com/envs/CartPole-v0) environment. Later you can change the code below to explore other [environments](https://gym.openai.com/envs/) and solve different tasks.
#
# *Note: The policy implemented in this notebook is designed to work on environments with a discrete action space. Extending the code to also handle environments with a continuous action space is left as an optional exercise.*

# %%
# create gym environment
env = gym.make('CartPole-v0')
# Out:
# [2017-10-22 12:56:11,669] Making new env: CartPole-v0

# %% [markdown]
# Let us see how the environment looks when we just take random actions.

# %%
# demo the environment
env.reset() # reset the environment
view = Viewer(env, custom_render=True) # we use this custom viewer to render the environment inline in the notebook
for _ in range(200):
    view.render()
    # env.render() # uncomment this to use gym's own render function
    env.step(env.action_space.sample()) # take a random action
view.render(close=True, display_gif=True) # display the environment inline in the notebook
# env.render(close=True) # uncomment this to use gym'm own render function
# Out:
# [2017-10-22 12:56:11,822] You are calling 'step()' even though this environment has already returned done = True. You should always call 'reset()' once you receive 'done = True' -- any further steps are undefined behavior.
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgBLNKURNTDVRLDJPD">
#     <br>
#     <input id="_anim_sliderBLNKURNTDVRLDJPD" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animBLNKURNTDVRLDJPD.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animBLNKURNTDVRLDJPD.slower()">&#8211;</button>
#     <button onclick="animBLNKURNTDVRLDJPD.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBLNKURNTDVRLDJPD.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBLNKURNTDVRLDJPD.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBLNKURNTDVRLDJPD.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animBLNKURNTDVRLDJPD.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBLNKURNTDVRLDJPD.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBLNKURNTDVRLDJPD.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animBLNKURNTDVRLDJPD.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectBLNKURNTDVRLDJPD" class="anim_control">
#     <input type="radio" name="state" value="once" checked> Once </input>
#     <input type="radio" name="state" value="loop" > Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgBLNKURNTDVRLDJPD";
#     var slider_id = "_anim_sliderBLNKURNTDVRLDJPD";
#     var loop_select_id = "_anim_loop_selectBLNKURNTDVRLDJPD";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %% [markdown]
# Taking random actions does not do a very good job at balancing the pole. Let us now apply the Policy Gradient method described above to solve this task!
#
# To start with, our policy will be a rather simple neural network with one hidden layer. We can retrieve the shape of the state space (input) and action space (output) from the environment.

# %%
# setup policy network
n_inputs = env.observation_space.shape[0]
n_hidden = 20
n_outputs = env.action_space.n

tf.reset_default_graph()

states_pl = tf.placeholder(tf.float32, [None, n_inputs], name='states_pl')
actions_pl = tf.placeholder(tf.int32, [None, n_outputs], name='actions_pl')
advantages_pl = tf.placeholder(tf.float32, [None], name='advantages_pl')
learning_rate_pl = tf.placeholder(tf.float32, name='learning_rate_pl')

l_hidden = tf.layers.dense(inputs=states_pl, units=n_hidden, activation=relu, name='l_hidden')
l_hidden2= tf.layers.dense(inputs=l_hidden, units=15, activation=relu, name='l_hidden2')
l_hidden3= tf.layers.dense(inputs=l_hidden2, units=10, activation=relu, name='l_hidden3')
l_out = tf.layers.dense(inputs=l_hidden3, units=n_outputs, activation=softmax, name='l_out')

# print network
print('states_pl:', states_pl.get_shape())
print('actions_pl:', actions_pl.get_shape())
print('advantages_pl:', advantages_pl.get_shape())
print('l_hidden:', l_hidden.get_shape())
print('l_out:', l_out.get_shape())
# Out:
# states_pl: (?, 4)
# actions_pl: (?, 2)
# advantages_pl: (?,)
# l_hidden: (?, 20)
# l_out: (?, 2)

# %%
# define loss and optimizer
loss_f = -tf.reduce_mean(tf.multiply(tf.log(tf.gather_nd(l_out, actions_pl)), advantages_pl))

optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate_pl)
train_f = optimizer.minimize(loss_f)

saver = tf.train.Saver() # we use this later to save the model

# %%
# test forward pass
state = env.reset()
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    action_probabilities = sess.run(fetches=l_out, feed_dict={states_pl: [state]})
print(state)
print(action_probabilities)
# Out:
# [-0.00095606 -0.01673782 -0.00301736 -0.01165348]
# [[ 0.49995974  0.50004023]]

# %% [markdown]
# *Note: As we create our solution, we will make very few assumptions about the cart-pole environment. We aim to develop a general model for solving reinforcement learning problems, and therefore care little about the specific meaning of the inputs and outputs.*

# %%
# helper functions

def get_rollout(sess, env, rollout_limit=None, stochastic=False, seed=None):
    """Generate rollout by iteratively evaluating the current policy on the environment."""
    rollout_limit = rollout_limit or env.spec.timestep_limit
    env.seed(seed)
    s = env.reset()
    states, actions, rewards = [], [], []
    for i in range(rollout_limit):
        a = get_action(sess, s, stochastic)
        s1, r, done, _ = env.step(a)
        states.append(s)
        actions.append(a)
        rewards.append(r)
        s = s1
        if done: break
    env.seed(None)
    return states, actions, rewards, i+1

def get_action(sess, state, stochastic=False):
    """Choose an action, given a state, with the current policy network."""
    # get action probabilities
    a_prob = sess.run(fetches=l_out, feed_dict={states_pl: np.atleast_2d(state)})
    if stochastic:
        # sample action from distribution
        return (np.cumsum(np.asarray(a_prob)) > np.random.rand()).argmax()
    else:
        # select action with highest probability
        return a_prob.argmax()

def get_advantages(rewards, rollout_limit, discount_factor, eps=1e-12):
    """Compute advantages"""
    returns = get_returns(rewards, rollout_limit, discount_factor)
    # standardize columns of returns to get advantages
    advantages = (returns - np.mean(returns, axis=0)) / (np.std(returns, axis=0) + eps)
    # restore original rollout lengths
    advantages = [adv[:len(rewards[i])] for i, adv in enumerate(advantages)]
    return advantages

def get_returns(rewards, rollout_limit, discount_factor):
    """Compute the cumulative discounted rewards, a.k.a. returns."""
    returns = np.zeros((len(rewards), rollout_limit))
    for i, r in enumerate(rewards):
        returns[i, len(r) - 1] = r[-1]
        for j in reversed(range(len(r)-1)):
            returns[i,j] = r[j] + discount_factor * returns[i,j+1]
    return returns

# %%
# training settings

epochs = 300 # number of training batches
batch_size = 2000 # number of timesteps in a batch
rollout_limit = 400#env.spec.timestep_limit # max rollout length
discount_factor = 0.9 # reward discount factor (gamma), 1.0 = no discount
learning_rate = 0.002 # you know this by now
early_stop_loss = 0 # stop training if loss < early_stop_loss, 0 or False to disable

# train policy network

try:
    statistics = []
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        print('start training')
        for epoch in range(epochs):
            # generate rollouts until batch_size total timesteps are collected
            states, actions, rewards = [], [], []
            timesteps = 0
            while timesteps < batch_size:
                _rollout_limit = min(rollout_limit, batch_size - timesteps) # limit rollout to match batch_size
                s, a, r, t = get_rollout(sess, env, _rollout_limit, stochastic=True, seed=epoch)            
                states.append(s)
                actions.append(a)
                rewards.append(r)
                timesteps += t
            # compute advantages
            advantages = get_advantages(rewards, rollout_limit, discount_factor)
            # policy gradient update
            loss, _ = sess.run(fetches=[loss_f, train_f], feed_dict={
                states_pl: np.concatenate(states),
                actions_pl: np.column_stack((np.arange(timesteps), np.concatenate(actions))),
                advantages_pl: np.concatenate(advantages),
                learning_rate_pl: learning_rate
            })            
            # validation
            val_rewards = [get_rollout(sess, env, rollout_limit, stochastic=False, seed=(epochs+i))[2] for i in range(10)]
            # store and print training statistics
            mtr = np.mean([np.sum(r) for r in rewards])
            mvr = np.mean([np.sum(r) for r in val_rewards])
            statistics.append((mtr, mvr, loss))
            print('%4d. training reward: %6.2f, validation reward: %6.2f, loss: %7.4f' % (epoch+1, mtr, mvr, loss))
            # early stopping
            if early_stop_loss and loss < early_stop_loss: break
        print('done')
        # save session
        saver.save(sess, 'tmp/model.ckpt')
except KeyboardInterrupt:
    pass
# Out:
# start training
#    1. training reward:  20.41, validation reward:   9.00, loss:  0.4566
#    2. training reward:  19.80, validation reward:  10.90, loss:  0.4489
#    3. training reward:  20.41, validation reward:  10.60, loss:  0.5526
#    4. training reward:  20.00, validation reward:  12.60, loss:  0.4097
#    5. training reward:  21.74, validation reward:  18.20, loss:  0.4183
#    6. training reward:  20.20, validation reward:  30.70, loss:  0.4174
#    7. training reward:  22.73, validation reward:  34.40, loss:  0.4532
#    8. training reward:  22.73, validation reward:  36.20, loss:  0.4561
#    9. training reward:  21.28, validation reward:  46.50, loss:  0.4070
#   10. training reward:  23.81, validation reward:  47.60, loss:  0.4505
#   11. training reward:  21.74, validation reward:  54.50, loss:  0.4360
#   12. training reward:  21.51, validation reward:  63.80, loss:  0.3920
#   13. training reward:  22.99, validation reward:  80.20, loss:  0.5296
#   14. training reward:  22.47, validation reward:  86.70, loss:  0.3962
#   15. training reward:  21.05, validation reward:  93.00, loss:  0.4503
#   16. training reward:  22.47, validation reward:  93.30, loss:  0.4071
#   17. training reward:  25.97, validation reward:  75.50, loss:  0.4338
#   18. training reward:  22.99, validation reward:  66.00, loss:  0.5221
#   19. training reward:  25.32, validation reward:  56.90, loss:  0.5091
#   20. training reward:  20.20, validation reward:  54.20, loss:  0.4608
#   21. training reward:  20.62, validation reward:  52.10, loss:  0.4239
#   22. training reward:  23.26, validation reward:  52.00, loss:  0.4581
#   23. training reward:  22.99, validation reward:  52.70, loss:  0.3913
#   24. training reward:  25.00, validation reward:  54.90, loss:  0.6335
#   25. training reward:  24.39, validation reward:  54.30, loss:  0.4977
#   26. training reward:  22.47, validation reward:  54.20, loss:  0.4132
#   27. training reward:  26.32, validation reward:  54.60, loss:  0.4238
#   28. training reward:  25.64, validation reward:  70.70, loss:  0.3971
#   29. training reward:  25.32, validation reward:  71.10, loss:  0.3854
#   30. training reward:  25.00, validation reward:  72.20, loss:  0.4623
#   31. training reward:  27.40, validation reward:  63.60, loss:  0.4336
#   32. training reward:  27.03, validation reward:  63.70, loss:  0.4237
#   33. training reward:  24.10, validation reward:  63.60, loss:  0.4527
#   34. training reward:  28.57, validation reward:  63.10, loss:  0.4494
#   35. training reward:  26.32, validation reward:  64.30, loss:  0.4238
#   36. training reward:  28.57, validation reward:  70.80, loss:  0.4232
#   37. training reward:  28.17, validation reward:  71.70, loss:  0.4768
#   38. training reward:  28.17, validation reward:  70.50, loss:  0.6629
#   39. training reward:  28.99, validation reward:  55.00, loss:  0.4388
#   40. training reward:  29.41, validation reward:  53.30, loss:  0.4068
#   41. training reward:  27.78, validation reward:  52.90, loss:  0.4754
#   42. training reward:  25.32, validation reward:  52.30, loss:  0.3897
#   43. training reward:  28.99, validation reward:  52.10, loss:  0.3990
#   44. training reward:  27.03, validation reward:  52.30, loss:  0.4701
#   45. training reward:  29.41, validation reward:  52.70, loss:  0.4439
#   46. training reward:  32.79, validation reward:  52.30, loss:  0.4084
#   47. training reward:  34.48, validation reward:  52.70, loss:  0.5142
#   48. training reward:  29.41, validation reward:  52.80, loss:  0.4064
#   49. training reward:  32.79, validation reward:  53.30, loss:  0.4293
#   50. training reward:  30.77, validation reward:  53.40, loss:  0.4626
#   51. training reward:  32.79, validation reward:  54.20, loss:  0.5358
#   52. training reward:  40.00, validation reward:  56.50, loss:  0.4771
#   53. training reward:  40.00, validation reward:  56.50, loss:  0.5605
#   54. training reward:  36.36, validation reward:  56.80, loss:  0.4462
#   55. training reward:  44.44, validation reward:  57.40, loss:  0.3705
#   56. training reward:  35.71, validation reward:  57.50, loss:  0.3975
#   57. training reward:  45.45, validation reward:  58.30, loss:  0.4146
#   58. training reward:  41.67, validation reward:  58.70, loss:  0.3870
#   59. training reward:  39.22, validation reward:  59.40, loss:  0.3648
#   60. training reward:  41.67, validation reward:  60.00, loss:  0.3916
#   61. training reward:  40.82, validation reward:  60.50, loss:  0.4067
#   62. training reward:  47.62, validation reward:  60.80, loss:  0.4384
#   63. training reward:  47.62, validation reward:  62.50, loss:  0.3964
#   64. training reward:  51.28, validation reward:  62.90, loss:  0.4692
#   65. training reward:  41.67, validation reward:  63.20, loss:  0.5240
#   66. training reward:  45.45, validation reward:  64.00, loss:  0.3883
#   67. training reward:  45.45, validation reward:  71.60, loss:  0.3360
#   68. training reward:  42.55, validation reward:  73.50, loss:  0.3642
#   69. training reward:  46.51, validation reward:  73.70, loss:  0.3329
#   70. training reward:  54.05, validation reward:  76.10, loss:  0.4124
#   71. training reward:  54.05, validation reward:  77.50, loss:  0.3716
#   72. training reward:  47.62, validation reward:  86.90, loss:  0.3744
#   73. training reward:  51.28, validation reward:  87.20, loss:  0.3379
#   74. training reward:  46.51, validation reward:  90.80, loss:  0.3825
#   75. training reward:  57.14, validation reward:  92.80, loss:  0.3364
#   76. training reward:  76.92, validation reward: 114.80, loss:  0.3666
#   77. training reward:  68.97, validation reward: 124.60, loss:  0.3732
#   78. training reward:  66.67, validation reward: 124.20, loss:  0.3292
#   79. training reward:  68.97, validation reward: 125.70, loss:  0.4034
#   80. training reward:  58.82, validation reward: 121.30, loss:  0.3953
#   81. training reward:  76.92, validation reward: 109.40, loss:  0.3669
#   82. training reward:  66.67, validation reward: 105.10, loss:  0.3764
#   83. training reward:  74.07, validation reward: 102.40, loss:  0.3504
#   84. training reward:  80.00, validation reward:  96.30, loss:  0.3748
#   85. training reward:  74.07, validation reward:  88.30, loss:  0.3550
#   86. training reward:  80.00, validation reward:  83.80, loss:  0.3901
#   87. training reward:  48.78, validation reward:  84.80, loss:  0.3939
#   88. training reward:  80.00, validation reward:  88.50, loss:  0.3861
#   89. training reward:  74.07, validation reward: 104.20, loss:  0.3282
#   90. training reward:  83.33, validation reward: 115.60, loss:  0.4151
#   91. training reward:  74.07, validation reward: 134.10, loss:  0.3737
#   92. training reward:  83.33, validation reward: 145.00, loss:  0.4442
#   93. training reward:  95.24, validation reward: 159.50, loss:  0.4013
#   94. training reward:  76.92, validation reward: 172.30, loss:  0.3301
#   95. training reward: 100.00, validation reward: 182.10, loss:  0.4077
#   96. training reward: 100.00, validation reward: 183.90, loss:  0.3370
#   97. training reward: 133.33, validation reward: 179.90, loss:  0.2284
#   98. training reward: 105.26, validation reward: 175.30, loss:  0.2759
#   99. training reward: 117.65, validation reward: 173.70, loss:  0.2960
#  100. training reward: 105.26, validation reward: 168.70, loss:  0.2891
#  101. training reward: 142.86, validation reward: 163.60, loss:  0.1912
#  102. training reward: 111.11, validation reward: 167.00, loss:  0.3747
#  103. training reward: 111.11, validation reward: 171.70, loss:  0.3200
#  104. training reward: 117.65, validation reward: 180.00, loss:  0.3403
#  105. training reward: 105.26, validation reward: 188.60, loss:  0.3498
#  106. training reward: 125.00, validation reward: 194.90, loss:  0.2720
#  107. training reward: 142.86, validation reward: 199.20, loss:  0.2480
#  108. training reward: 166.67, validation reward: 200.00, loss:  0.1643
#  109. training reward: 153.85, validation reward: 200.00, loss:  0.2235
#  110. training reward: 142.86, validation reward: 200.00, loss:  0.1855
#  111. training reward: 166.67, validation reward: 200.00, loss:  0.1972
#  112. training reward: 181.82, validation reward: 200.00, loss:  0.0734
#  113. training reward: 166.67, validation reward: 200.00, loss:  0.2202
#  114. training reward: 153.85, validation reward: 200.00, loss:  0.2398
#  115. training reward: 166.67, validation reward: 200.00, loss:  0.2081
#  116. training reward: 166.67, validation reward: 200.00, loss:  0.2232
#  117. training reward: 166.67, validation reward: 200.00, loss:  0.2077
#  118. training reward: 181.82, validation reward: 200.00, loss:  0.0938
#  119. training reward: 181.82, validation reward: 200.00, loss:  0.1374
#  120. training reward: 181.82, validation reward: 200.00, loss:  0.1496
#  121. training reward: 181.82, validation reward: 200.00, loss:  0.1520
#  122. training reward: 181.82, validation reward: 200.00, loss:  0.1115
#  123. training reward: 181.82, validation reward: 200.00, loss:  0.0828
#  124. training reward: 181.82, validation reward: 200.00, loss:  0.1603
#  125. training reward: 181.82, validation reward: 200.00, loss:  0.0626
#  126. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  127. training reward: 181.82, validation reward: 200.00, loss:  0.1154
#  128. training reward: 181.82, validation reward: 200.00, loss:  0.1602
#  129. training reward: 181.82, validation reward: 200.00, loss:  0.1578
#  130. training reward: 181.82, validation reward: 200.00, loss:  0.0982
#  131. training reward: 166.67, validation reward: 200.00, loss:  0.0987
#  132. training reward: 166.67, validation reward: 200.00, loss:  0.1935
#  133. training reward: 181.82, validation reward: 195.20, loss:  0.1083
#  134. training reward: 166.67, validation reward: 194.00, loss:  0.1022
#  135. training reward: 181.82, validation reward: 193.70, loss:  0.1224
#  136. training reward: 166.67, validation reward: 193.70, loss:  0.1999
#  137. training reward: 166.67, validation reward: 193.70, loss:  0.1777
#  138. training reward: 166.67, validation reward: 193.90, loss:  0.1467
#  139. training reward: 166.67, validation reward: 196.90, loss:  0.0921
#  140. training reward: 181.82, validation reward: 200.00, loss:  0.1123
#  141. training reward: 181.82, validation reward: 200.00, loss:  0.1243
#  142. training reward: 181.82, validation reward: 200.00, loss:  0.0614
#  143. training reward: 181.82, validation reward: 200.00, loss:  0.1368
#  144. training reward: 181.82, validation reward: 200.00, loss:  0.1023
#  145. training reward: 181.82, validation reward: 200.00, loss:  0.1444
#  146. training reward: 181.82, validation reward: 200.00, loss:  0.1041
#  147. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  148. training reward: 181.82, validation reward: 200.00, loss:  0.1378
#  149. training reward: 166.67, validation reward: 200.00, loss:  0.2131
#  150. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  151. training reward: 181.82, validation reward: 200.00, loss:  0.0775
#  152. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  153. training reward: 181.82, validation reward: 200.00, loss:  0.1186
#  154. training reward: 181.82, validation reward: 200.00, loss:  0.0981
#  155. training reward: 181.82, validation reward: 200.00, loss:  0.1089
#  156. training reward: 181.82, validation reward: 200.00, loss:  0.0795
#  157. training reward: 181.82, validation reward: 200.00, loss:  0.1202
#  158. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  159. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  160. training reward: 181.82, validation reward: 200.00, loss:  0.1457
#  161. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  162. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  163. training reward: 181.82, validation reward: 200.00, loss:  0.1116
#  164. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  165. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  166. training reward: 181.82, validation reward: 200.00, loss:  0.1252
#  167. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  168. training reward: 181.82, validation reward: 200.00, loss:  0.1606
#  169. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  170. training reward: 181.82, validation reward: 200.00, loss:  0.1353
#  171. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  172. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  173. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  174. training reward: 181.82, validation reward: 200.00, loss:  0.1388
#  175. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  176. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  177. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  178. training reward: 200.00, validation reward: 200.00, loss:  0.0000
#  179. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  180. training reward: 181.82, validation reward: 200.00, loss:  0.1615
#  181. training reward: 181.82, validation reward: 200.00, loss:  0.1333
#  182. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  183. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  184. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  185. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  186. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  187. training reward: 181.82, validation reward: 200.00, loss:  0.1392
#  188. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  189. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  190. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  191. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  192. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  193. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  194. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  195. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  196. training reward: 181.82, validation reward: 200.00, loss:  0.1431
#  197. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  198. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  199. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  200. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  201. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  202. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  203. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  204. training reward: 181.82, validation reward: 200.00, loss:  0.1387
#  205. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  206. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  207. training reward: 181.82, validation reward: 200.00, loss:  0.1254
#  208. training reward: 181.82, validation reward: 200.00, loss:  0.1259
#  209. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  210. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  211. training reward: 181.82, validation reward: 200.00, loss:  0.1522
#  212. training reward: 181.82, validation reward: 200.00, loss:  0.0829
#  213. training reward: 181.82, validation reward: 200.00, loss:  0.0763
#  214. training reward: 181.82, validation reward: 200.00, loss:  0.1267
#  215. training reward: 181.82, validation reward: 200.00, loss:  0.1319
#  216. training reward: 166.67, validation reward: 199.00, loss:  0.1910
#  217. training reward: 181.82, validation reward: 188.60, loss:  0.0547
#  218. training reward: 181.82, validation reward: 184.60, loss:  0.0710
#  219. training reward: 181.82, validation reward: 183.60, loss:  0.0932
#  220. training reward: 153.85, validation reward: 187.90, loss:  0.0925
#  221. training reward: 153.85, validation reward: 196.10, loss:  0.1496
#  222. training reward: 181.82, validation reward: 200.00, loss:  0.0455
#  223. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  224. training reward: 181.82, validation reward: 200.00, loss:  0.1319
#  225. training reward: 181.82, validation reward: 200.00, loss:  0.1505
#  226. training reward: 181.82, validation reward: 200.00, loss:  0.1269
#  227. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  228. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  229. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  230. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  231. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  232. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  233. training reward: 181.82, validation reward: 200.00, loss:  0.1190
#  234. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  235. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  236. training reward: 181.82, validation reward: 200.00, loss:  0.1337
#  237. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  238. training reward: 181.82, validation reward: 200.00, loss:  0.1209
#  239. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  240. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  241. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  242. training reward: 181.82, validation reward: 200.00, loss:  0.1210
#  243. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  244. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  245. training reward: 181.82, validation reward: 200.00, loss:  0.1495
#  246. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  247. training reward: 181.82, validation reward: 200.00, loss:  0.1227
#  248. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  249. training reward: 181.82, validation reward: 200.00, loss:  0.1548
#  250. training reward: 181.82, validation reward: 200.00, loss:  0.1458
#  251. training reward: 181.82, validation reward: 200.00, loss:  0.0839
#  252. training reward: 181.82, validation reward: 200.00, loss:  0.1024
#  253. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  254. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  255. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  256. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  257. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  258. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  259. training reward: 200.00, validation reward: 200.00, loss:  0.0000
#  260. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  261. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  262. training reward: 181.82, validation reward: 200.00, loss:  0.1481
#  263. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  264. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  265. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  266. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  267. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  268. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  269. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  270. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  271. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  272. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  273. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  274. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  275. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  276. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  277. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  278. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  279. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  280. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  281. training reward: 200.00, validation reward: 200.00, loss:  0.0000
#  282. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  283. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  284. training reward: 200.00, validation reward: 200.00, loss:  0.0000
#  285. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  286. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  287. training reward: 181.82, validation reward: 200.00, loss:  0.1473
#  288. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  289. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  290. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  291. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  292. training reward: 181.82, validation reward: 200.00, loss:  0.1526
#  293. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  294. training reward: 181.82, validation reward: 200.00, loss:  0.1416
#  295. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  296. training reward: 200.00, validation reward: 200.00, loss:  0.0000
#  297. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  298. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  299. training reward: 200.00, validation reward: 200.00, loss:  0.0001
#  300. training reward: 200.00, validation reward: 200.00, loss:  0.0001
# done

# %%
# plot training statistics
statistics = np.array(statistics).T
mean_training_rewards = statistics[0]
mean_validation_rewards = statistics[1]
losses = statistics[2]

plt.figure(figsize=(10,6))
plt.subplot(211)
plt.plot(losses, label='loss')
plt.xlabel('epoch'); plt.ylabel('loss')
plt.xlim((0, len(losses)))
plt.legend(loc=1); plt.grid()
plt.subplot(212)
plt.plot(mean_training_rewards, label='mean training reward')
plt.plot(mean_validation_rewards, label='mean validation reward')
plt.xlabel('epoch'); plt.ylabel('mean reward')
plt.xlim((0, len(mean_validation_rewards)))
plt.legend(loc=4); plt.grid()
plt.tight_layout(); plt.show()

# %%
# review solution
with tf.Session() as sess:
    saver.restore(sess, "tmp/model.ckpt")
    s = env.reset()
    view = Viewer(env, custom_render=True)
    for _ in range(800):
        view.render()
        a = get_action(sess, s, stochastic=False)
        s, r, done, _ = env.step(a)
    view.render(close=True, display_gif=True)
# Out:
# INFO:tensorflow:Restoring parameters from tmp/model.ckpt
# [2017-10-22 13:07:55,714] Restoring parameters from tmp/model.ckpt
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgIEHDJDLDIHVWMYGR">
#     <br>
#     <input id="_anim_sliderIEHDJDLDIHVWMYGR" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animIEHDJDLDIHVWMYGR.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animIEHDJDLDIHVWMYGR.slower()">&#8211;</button>
#     <button onclick="animIEHDJDLDIHVWMYGR.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIEHDJDLDIHVWMYGR.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIEHDJDLDIHVWMYGR.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIEHDJDLDIHVWMYGR.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animIEHDJDLDIHVWMYGR.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIEHDJDLDIHVWMYGR.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIEHDJDLDIHVWMYGR.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animIEHDJDLDIHVWMYGR.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectIEHDJDLDIHVWMYGR" class="anim_control">
#     <input type="radio" name="state" value="once" checked> Once </input>
#     <input type="radio" name="state" value="loop" > Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgIEHDJDLDIHVWMYGR";
#     var slider_id = "_anim_sliderIEHDJDLDIHVWMYGR";
#     var loop_select_id = "_anim_loop_selectIEHDJDLDIHVWMYGR";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %% [markdown]
# ## Exercises
#
# Now it is your turn! Play around the code above and try to make it learn better and faster.
#
# Experiment with the:
#
# * number of timesteps in a batch.
# * max length of rollouts.
# * discount factor.
# * learning rate.
# * number of hidden units and layers.
#
#
# ### Exercise 1
#
# *Describe any changes you made to the code and why you think they improve the agent. Are you able to get solutions consistently?*
#
# #### Answer 1)
#
# I changed the model to 3 layers with inputs: 20, 15, 10. Epochs: 300, batch_size: 2000, rollout: 400, discount: 0.9, learning_rate = 0.001. The mayor improvement of the model comes from the batch_size being bigger as this describes the number of timesteps in a batch and therefore the amount of time we look into the future. Also with 2 hidden layers more complex features can be learned.
# The solution obtained using these parameters will stabilize the pendulum consistently.
#
# ### Exercise 2
#
# *Consider the following sequence of rewards produced by an agent interacting with an environment for 10 timesteps: [0, 1, 1, 1, 0, 1, 1, 0, 0, 0].*
#
# * *What is the total reward?*
# * *What is the total future reward in each timestep?*
# * *What is the discounted future reward in each timestep if $\gamma = 0.9$?*
#
# *[Hint: See previous notebook.]*
#
# #### Answer 2)
#
# Total reward:
#
# $$R = 0+1+1+1+0+1+1+0+0+0 = 5$$
#
# Total future reward at each timestep:
#
# \begin{align}
# R_0 &= 0+1+1+1+0+1+1+0+0+0 = 5 \\
# R_1 &= 1+1+1+0+1+1+0+0+0 = 5 \\
# R_2 &= 1+1+0+1+1+0+0+0= 4 \\
# R_3 &= 1+0+1+1+0+0+0 = 3 \\
# R_4 &= 0+1+1+0+0+0 = 2 \\
# R_5 &= 1+1+0+0+0 = 2 \\
# R_6 &= 1+0+0+0 = 1 \\
# R_7 &= R_8 = R_9 = 0
# \end{align}
#
# Discounted future reward in each timestep if $\gamma = 0.9$:
#
# \begin{align}
# R_0 &= 0+0.9\cdot5 = 4.5 \\
# R_1 &= 1+0.9\cdot4 = 4.6 \\
# R_2 &= 1+0.9\cdot= 3.7 \\
# R_3 &= 1+0.9\cdot2 = 2.8 \\
# R_4 &= 0+0.9\cdot2 = 1.8 \\
# R_5 &= 1+0.9\cdot1 = 1.9 \\
# R_6 &= 1+0.9\cdot0= 1 \\
# R_7 &= R_8 = R_9 = 0+0.9\cdot0 = 0
# \end{align}
#
#
# ### Exercise 3
#
# *In the plot of the training and validation mean reward above, you will sometimes see the validation reward starts out lower than the training reward but later they cross. How can you explain this behavior? [Hint: Do we use the policy network in the same way during training and validation?]*
#
# #### Answer 3)
#
# In training we get the keep getting rollouts until timesteps reaches the batch size. For validation we get one rollout for a fixed length (here from 0 to 9). From above we now that the reward is calculated as a sum. Hence, we have difference in training and validation reward. This could also mean that in the beginning the model haven't sufficient to actually perform when validating, but when the learning really starts to kick in after some epochs, the validation will exceed the training.
#
# ### Exercise 4
#
# *How does the policy gradient method we have used address the exploration-exploitation dilemma (see the previous notebook for definition)?*
#
# #### Answer 4)
#
# At first all actions have equal probability, meaning the choice is random. When training, the network learns which actions are good and therefor moves away from the exploration and tips more into exploitation. The learning rate determines how much (or how fast) we go into the exploitation. Larger learning rate means reducing the exploration.

# %% [markdown]
# # Exercise from book
#
# ## Write out Equation (22) in component form, and verify that it gives the same result as the rule (4) for computing the output of a sigmoid neuron.
#
# (22):
#
# $$a' = \sigma(wa+b)$$
#
# a' is the output of a layer, and a is the input. As w, and b are vectors and the sigmoid is applied elementvise, that would be same as (pseudo)
#
#     for j = 0:n-1
#          a'(j) = sigma(w(j)*a(j)+b(j)
# where $$\sigma = 1/(1+exp(-z))$$
#
# keeping in mind that a' is output and a is input would give
#
# \begin{align}
# output &= 1/(1+exp(-(\sum{w(j)x(j)+b(j)})) \\
# output &= 1/(1+exp(-\sum{w(j)x(j)-b(j)})
# \end{align}
